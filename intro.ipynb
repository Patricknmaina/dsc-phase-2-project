# %%
from IPython.display import Image, display

display(Image(filename=r'C:\Users\Admin\Documents\Moringa Learning\PROJECTS\Phase_2project\dsc-phase-1-project-template\cinema 02.jpg'))

# %% [markdown]
# ## 📽️ Box Office Performance Analysis - Project Introduction
# Business Context
# In the evolving entertainment landscape, major companies are increasingly investing in original movie content to capture audience attention and drive growth. Our company is now launching a new movie studio to enter this competitive market. However, without prior experience in film production, strategic, data-driven insights are critical to ensuring our success.
#
# This project explores movie industry data to uncover what factors drive box office success, helping us recommend the types of movies our new studio should prioritize.
#
# ## Project Goals 🎯
# Analyze domestic vs. international box office trends to understand market dynamics.
#
# Identify top-performing film genres, production budgets, and release periods linked to high box office returns.
#
# Investigate how movie ratings (IMDb, content ratings like PG-13, R) relate to audience reception and revenue.
#
# Support decision-making by translating findings into clear, actionable recommendations.
#
# Recommend specific strategies for our new studio:
# ➔ What types of films to produce,
# ➔ When to release them,
# ➔ How to allocate production budgets wisely
#
# ## Data Sources 📁
# We will be working with real-world datasets collected from:
#
# ### 1. Box Office Mojo.
#
# - Gross earnings data, we understand how much money movies actually made.
#
# - Provides detailed information about movies' domestic and international box office revenues.
#
#
# ### 2. IMDb.
#
# - Offers information on genres, movie titles, release dates, runtime, and audience ratings.
#
# - This will help us analyze how movie content and quality relate to success.
#
# ### 3. The Numbers
# - upplies production budget estimates and deeper financial metrics/ statistics.
#
# - This is crucial to finding out how much was spent to make the movies and whether it paid off.
#
# ### Main features analyzed include:
#
# Movie title
#
# Genre(s)
#
# Box office earnings
#
# Production budget
#
# Release date
#
# IMDb rating
#
# ### Specifically, we are working with these datasets:
#
# bom.movie_gross.csv: Gross earnings (domestic and international).
#
# im.db SQLite database:
#
# movie_basics table — Contains movie title, genre, runtime, and release year.
#
# movie_ratings table — Contains average IMDb ratings and number of votes.
#
# ## Workflow Overview 📊
#
# ### 1.Understand the Business Problem
# Define the key questions and success criteria for the new movie studio.
#
# We reviewed what the company needed: actionable advice on what kind of movies to produce and how to position them.
#
# EXAMPLES:
#
# What types of movies (genre, style, content) are doing well at the box office?
#
# When should these movies be released to get the best audience response?
#
# How much should they be investing — should they go for big-budget productions, or are smaller, smartly-made movies equally profitable?
#
# What audiences should they target based on ratings like PG-13, R, etc.?
#
# Should they prioritize domestic (local) markets or international markets for their success?
#
# ### 2.Data Acquisition and Familiarization
# Collect and explore datasets:
#
# We gathered datasets from Box Office Mojo, IMDb, and The Numbers.
#
# We inspected key attributes like movie genres, runtime, box office earnings, production budgets, release years, and audience ratings.
#
# ## 3.Data Cleaning and Preparation
#
# Handle missing and inconsistent values, removed duplicates.
#
# Standardize formats across datasets.
#
# Engineer new features (e.g., single vs multi-genre classification).
#
# ### 4.Exploratory Data Analysis (EDA)
#
# Visualize and investigate trends between genres, budgets, ratings, and earnings.
#
# Here we will Use correlation heatmaps, bar plots, histograms, and box plots for insights.
#
# ### 5.Hypothesis Testing
# Conduct statistical tests to validate or reject assumptions such as:
#
# Do higher-budget films consistently outperform low-budget ones?
#
# Are PG-13 rated movies more profitable than R-rated ones?
#
# Are movies released during holiday seasons more successful?
#
# ### 6.Insights and Recommendations
# Summarize findings to recommend:
#
# Best genres and budgets to focus on
#
# Ideal release windows
#
# Audience segments to target
